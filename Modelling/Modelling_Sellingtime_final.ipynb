# %% [markdown]
# ## Dummy coding

# %% [markdown]
# Our dataset contains categorical values that we want to use for the machine learning models. To realize this we will dummy code those variables

# %%
import numpy as np
import pandas as pd
#Reading File path
import os
os.chdir('/Users/pim/Downloads') 
os.getcwd()
# Out:
# '/Users/pim/Downloads'

# %%
#creating dataframe
funda = pd.read_csv('funda_time.csv')
funda.head()
# Out:
#    Unnamed: 0  selling_days  oppervlakte  aantalKamers  aantalBadkamers  \
# 0           0           104           62             3              1.0
# 1           1             0          136             5              1.0
# 2           2           113           70             3              1.0
# 3           3           132          144             5              1.0
# 4           4           123          323             8              1.0
#
#    koopPrijs energielabelKlasse  \
# 0   139000.0                  C
# 1   209000.0                  B
# 2   267500.0                  C
# 3   349000.0                  C
# 4   495000.0                  C
#
#                                volledigeOmschrijving categorieObject
# 0  Ruimte, vrijheid, en altijd het water en de we...        Woonhuis
# 1  Verrassend ruime tussenwoning nabij het centru...        Woonhuis
# 2  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...     Appartement
# 3  Wonen in een zeer royaal bemeten geschakelde 2...        Woonhuis
# 4  Landgoed Junne is een eeuwenoud landgoed en li...        Woonhuis

# %% [markdown]
# The columns that we will convert are 'energielabelKlasse', 'volledigeOmschrijving' and 'categorieObject'.
#
# For 'volledigeOmschrijving' we will extract numerical values from the text. We will do this using topic modelling

# %%
#Drops the index column

funda=funda[['selling_days', 'oppervlakte', 'aantalKamers', 'aantalBadkamers','koopPrijs', 'energielabelKlasse', 'volledigeOmschrijving', 'categorieObject']]
funda.head()
# Out:
#    selling_days  oppervlakte  aantalKamers  aantalBadkamers  koopPrijs  \
# 0           104           62             3              1.0   139000.0
# 1             0          136             5              1.0   209000.0
# 2           113           70             3              1.0   267500.0
# 3           132          144             5              1.0   349000.0
# 4           123          323             8              1.0   495000.0
#
#   energielabelKlasse                              volledigeOmschrijving  \
# 0                  C  Ruimte, vrijheid, en altijd het water en de we...
# 1                  B  Verrassend ruime tussenwoning nabij het centru...
# 2                  C  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...
# 3                  C  Wonen in een zeer royaal bemeten geschakelde 2...
# 4                  C  Landgoed Junne is een eeuwenoud landgoed en li...
#
#   categorieObject
# 0        Woonhuis
# 1        Woonhuis
# 2     Appartement
# 3        Woonhuis
# 4        Woonhuis

# %%
#Convert 'energielabelKlasse' and 'categorieObject' to values
funda_clean = pd.get_dummies(funda, prefix = ['energielabelKlasse', 'categorieObject'], columns=['energielabelKlasse', 'categorieObject'])
funda_clean.head()
# Out:
#    selling_days  oppervlakte  aantalKamers  aantalBadkamers  koopPrijs  \
# 0           104           62             3              1.0   139000.0
# 1             0          136             5              1.0   209000.0
# 2           113           70             3              1.0   267500.0
# 3           132          144             5              1.0   349000.0
# 4           123          323             8              1.0   495000.0
#
#                                volledigeOmschrijving  energielabelKlasse_A  \
# 0  Ruimte, vrijheid, en altijd het water en de we...                     0
# 1  Verrassend ruime tussenwoning nabij het centru...                     0
# 2  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...                     0
# 3  Wonen in een zeer royaal bemeten geschakelde 2...                     0
# 4  Landgoed Junne is een eeuwenoud landgoed en li...                     0
#
#    energielabelKlasse_A+  energielabelKlasse_A++  energielabelKlasse_A+++  \
# 0                      0                       0                        0
# 1                      0                       0                        0
# 2                      0                       0                        0
# 3                      0                       0                        0
# 4                      0                       0                        0
#
#    energielabelKlasse_A++++  energielabelKlasse_A+++++  energielabelKlasse_B  \
# 0                         0                          0                     0
# 1                         0                          0                     1
# 2                         0                          0                     0
# 3                         0                          0                     0
# 4                         0                          0                     0
#
#    energielabelKlasse_C  energielabelKlasse_D  energielabelKlasse_E  \
# 0                     1                     0                     0
# 1                     0                     0                     0
# 2                     1                     0                     0
# 3                     1                     0                     0
# 4                     1                     0                     0
#
#    energielabelKlasse_F  energielabelKlasse_G  categorieObject_Appartement  \
# 0                     0                     0                            0
# 1                     0                     0                            0
# 2                     0                     0                            1
# 3                     0                     0                            0
# 4                     0                     0                            0
#
#    categorieObject_Woonhuis
# 0                         1
# 1                         1
# 2                         0
# 3                         1
# 4                         1

# %% [markdown]
# ## Topic modelling

# %%
import pandas as pd
import numpy as np
import spacy #pip install -U spacy
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # to make jupyter print all outputs, not just the last one
import pickle
import os
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF
import re

# %%
#Clean description
funda_clean = funda_clean.replace('\n',' ', regex=True)
funda_clean = funda_clean.replace('\t',' ', regex=True)
funda_clean = funda_clean.replace('\n\n',' ', regex=True)
funda_clean = funda_clean.replace('\n\n\n',' ', regex=True)
funda_clean = funda_clean.replace('\n\n\n\n',' ', regex=True)
funda_clean = funda_clean.replace('\t',' ', regex=True)
funda_clean = funda_clean.replace('\t\t',' ', regex=True)
funda_clean = funda_clean.replace('\t\t\t',' ', regex=True)
funda_clean = funda_clean.replace('\t\t\t\t',' ', regex=True)

# %%
# Take text as vector
text = funda_clean['volledigeOmschrijving'].tolist()

# %%
#python -m spacy download nl_core_news_sm
# next, this command will load the dutch language model of spacy, which we have installed using the line above
nlp = spacy.load('nl_core_news_sm')
type(nlp)
# Out:
# spacy.lang.nl.Dutch

# %%
# Tokenize first description
text[0]

for token in nlp(text[0]):
    print(token)
# Out:
# 'Ruimte, vrijheid, en altijd het water en de weides om je heen. Met een tikkeltje romantiek, nostalgie, het voortdurende vakantiegevoel en vooral rust, is het leven op een woonark nét even anders. Op deze ark voelt u pas echt hoe het is om vrij te wonen. Stilletjes deinend, kabbelend water en voorbij zwemmende eendjes… Wij bieden u nu de kans om dit zelf te gaan ervaren!  Algemeen • Rustig gelegen in breed vaarwater • Nabij dorp met supermarkt, snackbar en café-restaurant • Landelijke omgeving • Omsloten tuin (300 m2) met berging op zuidoosten (gebruiksvergoeding aan gemeente) • Ligplaatscanon via Hollands Noorderkwartier • Garage en parkeerruimte aan de wegzijde  Omschrijving Alles is gelijkvloers in deze charmante woonark. Vanuit de tuin stapt u over de loopbrug de ark binnen en ervaart u direct de bijzondere sfeer van het wonen op het water. De corridor loopt over de gehele lengte van de ark. Links is de knusse woonkamer, met daarachter de keuken met koelkast, wasemkap en elektrische kookplaat. In de bijkeuken ernaast is voldoende ruimte voor bijvoorbeeld de vriezer en magnetron of oven. Er is een deur naar buiten, zodat u vanaf de omloop aan alle kanten van het schitterende uitzicht kunt genieten.  In het woongedeelte is het heerlijk vertoeven met uitzicht op het water aan de ene kant, en de mooie tuin aan de andere kant.  Doordat er vensters aan beide kanten van de ark zijn, is de lichtinval optimaal. De ramen in de woonkamer zijn geïsoleerd met zonwerende folie zodat het nooit té warm wordt in de ark. De ruimte is slim gebruikt door vouwdeuren te plaatsen. De ouderslaapkamer, de kleine slaapkamer en de badkamer zijn bereikbaar via de corridor en hebben kunststof kozijnen rond de ramen. In de kleine maar luxe badkamer bevindt zich het toilet, een wastafel en een heerlijke stoomcabine. Achterin de corridor is de cv-ruimte waar tevens de aansluiting voor de wasmachine en droger zit.  De heerlijke tuin biedt veel privacy doordat het perceel volledig omheind is. Het tuinhuis is recentelijk geïsoleerd en voorzien van elektra. Hier zijn de mogelijkheden eindeloos: een extra (slaap)kamer, een man cave, een bed & breakfast? Laat uw fantasie er op los en kijk eens wat er allemaal kan!  Uzelf, de heerlijke tuin, de ark en het water… Hoe mooi het leven kan zijn, wordt met deze woonark bevestigd. Kom sfeer proeven en voel de vrijheid!  In collegiale verkoop met Zuurbier Makelaardij  www.zuurbiermakelaardij.nl 06 5339 3945'
# Ruimte
# ,
# vrijheid
# ,
# en
# altijd
# het
# water
# en
# de
# weides
# om
# je
# heen
# .
# Met
# een
# tikkeltje
# romantiek
# ,
# nostalgie
# ,
# het
# voortdurende
# vakantiegevoel
# en
# vooral
# rust
# ,
# is
# het
# leven
# op
# een
# woonark
# nét
# even
# anders
# .
# Op
# deze
# ark
# voelt
# u
# pas
# echt
# hoe
# het
# is
# om
# vrij
# te
# wonen
# .
# Stilletjes
# deinend
# ,
# kabbelend
# water
# en
# voorbij
# zwemmende
# eendjes
# …
# Wij
# bieden
# u
# nu
# de
# kans
# om
# dit
# zelf
# te
# gaan
# ervaren
# !
#
# Algemeen
# •
# Rustig
# gelegen
# in
# breed
# vaarwater
# •
# Nabij
# dorp
# met
# supermarkt
# ,
# snackbar
# en
# café-restaurant
# •
# Landelijke
# omgeving
# •
# Omsloten
# tuin
# (
# 300
# m2
# )
# met
# berging
# op
# zuidoosten
# (
# gebruiksvergoeding
# aan
# gemeente
# )
# •
# Ligplaatscanon
# via
# Hollands
# Noorderkwartier
# •
# Garage
# en
# parkeerruimte
# aan
# de
# wegzijde
#
# Omschrijving
# Alles
# is
# gelijkvloers
# in
# deze
# charmante
# woonark
# .
# Vanuit
# de
# tuin
# stapt
# u
# over
# de
# loopbrug
# de
# ark
# binnen
# en
# ervaart
# u
# direct
# de
# bijzondere
# sfeer
# van
# het
# wonen
# op
# het
# water
# .
# De
# corridor
# loopt
# over
# de
# gehele
# lengte
# van
# de
# ark
# .
# Links
# is
# de
# knusse
# woonkamer
# ,
# met
# daarachter
# de
# keuken
# met
# koelkast
# ,
# wasemkap
# en
# elektrische
# kookplaat
# .
# In
# de
# bijkeuken
# ernaast
# is
# voldoende
# ruimte
# voor
# bijvoorbeeld
# de
# vriezer
# en
# magnetron
# of
# oven
# .
# Er
# is
# een
# deur
# naar
# buiten
# ,
# zodat
# u
# vanaf
# de
# omloop
# aan
# alle
# kanten
# van
# het
# schitterende
# uitzicht
# kunt
# genieten
# .
#
# In
# het
# woongedeelte
# is
# het
# heerlijk
# vertoeven
# met
# uitzicht
# op
# het
# water
# aan
# de
# ene
# kant
# ,
# en
# de
# mooie
# tuin
# aan
# de
# andere
# kant
# .
#
# Doordat
# er
# vensters
# aan
# beide
# kanten
# van
# de
# ark
# zijn
# ,
# is
# de
# lichtinval
# optimaal
# .
# De
# ramen
# in
# de
# woonkamer
# zijn
# geïsoleerd
# met
# zonwerende
# folie
# zodat
# het
# nooit
# té
# warm
# wordt
# in
# de
# ark
# .
# De
# ruimte
# is
# slim
# gebruikt
# door
# vouwdeuren
# te
# plaatsen
# .
# De
# ouderslaapkamer
# ,
# de
# kleine
# slaapkamer
# en
# de
# badkamer
# zijn
# bereikbaar
# via
# de
# corridor
# en
# hebben
# kunststof
# kozijnen
# rond
# de
# ramen
# .
# In
# de
# kleine
# maar
# luxe
# badkamer
# bevindt
# zich
# het
# toilet
# ,
# een
# wastafel
# en
# een
# heerlijke
# stoomcabine
# .
# Achterin
# de
# corridor
# is
# de
# cv-ruimte
# waar
# tevens
# de
# aansluiting
# voor
# de
# wasmachine
# en
# droger
# zit
# .
#
# De
# heerlijke
# tuin
# biedt
# veel
# privacy
# doordat
# het
# perceel
# volledig
# omheind
# is
# .
# Het
# tuinhuis
# is
# recentelijk
# geïsoleerd
# en
# voorzien
# van
# elektra
# .
# Hier
# zijn
# de
# mogelijkheden
# eindeloos
# :
# een
# extra
# (
# slaap
# )
# kamer
# ,
# een
# man
# cave
# ,
# een
# bed
# &
# breakfast
# ?
# Laat
# uw
# fantasie
# er
# op
# los
# en
# kijk
# eens
# wat
# er
# allemaal
# kan
# !
#
# Uzelf
# ,
# de
# heerlijke
# tuin
# ,
# de
# ark
# en
# het
# water
# …
# Hoe
# mooi
# het
# leven
# kan
# zijn
# ,
# wordt
# met
# deze
# woonark
# bevestigd
# .
# Kom
# sfeer
# proeven
# en
# voel
# de
# vrijheid
# !
#
# In
# collegiale
# verkoop
# met
# Zuurbier
# Makelaardij
#
# www.zuurbiermakelaardij.nl
# 06
# 5339
# 3945

# %%
# Entities recognition
for i in nlp(text[0]).ents:
    print(i, i.label_)
# Out:
# Stilletjes GPE
# ervaren! ORG
# Rustig GPE
# 300 m2 QUANTITY
# Ligplaatscanon NORP
# Hollands Noorderkwartier • FAC
# Omschrijving Alles PERSON
# cave NORP
# vrijheid! ORG
# Zuurbier NORP
# 06 5339 DATE

# %%
# Adding custom stop words before performing tokenization
nlp.Defaults.stop_words |= {"€", "II", "m.", "circa", "afm", "m", "x", "m³.", "ca.", "m³", "±", "m²", "vind", "minuten", "twee", "totaal", "1e", "2e", "+", "m2", "o.a.",}

# %%
# perform tokenization
docs = [nlp.make_doc(x) for x in text]

# %%
stopwords = nlp.Defaults.stop_words
print(stopwords)
# Out:
# {'ikke', 'der', 'gauw', 'na', 'minuten', 'anderzijds', 'gewoonweg', 'welke', 'hierboven', 'jullie', 'enz', 'ze', 'eersten', 'want', 'pas', 'm³', 'zo’n', 'in', 'ander', 'lang', 'ikzelf', 'u', 'zal', 'wezen', 'juist', 'zonder', 'buiten', 'prof', 'hele', 'daarnet', 'wordt', 'alles', 'sinds', 'terwijl', 'niets', 'al', 'haar', 'toen', 'alle', 'wil', 'enkele', 'ca.', 'm2', 'uw', 'weer', 'bovendien', 'ieder', 'betere', 'zullen', 'hij', 'inmiddels', 'daar', 'eerder', 'tijdens', 'bijna', 'daarop', 'me', 'aangezien', 'welken', 'overigens', 'zouden', 'jouwe', 'we', 'hierin', 'gedurende', 'er', 'als', 'zulks', 'of', 'uitgezonderd', 'thans', 'doch', 'jijzelf', 'elke', 'over', 'weg', 'hebt', 'liet', 'vooral', 'o.a.', 'vanuit', 'waar', 'sindsdien', 'mag', 'bovenstaand', 'doorgaans', 'enkel', 'zijne', 'hoe', 'ondertussen', 'is', 'zichzelf', 'nog', 'zelfde', 'm²', 'm.', 'zowat', 'boven', 'minder', 'zo', 'aan', 'sommige', 'toe', 'bijvoorbeeld', 'kunnen', 'alleen', 'zelf', 'zodra', 'afgelopen', 'weldra', 'omver', 'nogal', 'wilde', 'ge', 'zoveel', 'beter', 'geweest', 'door', 'mochten', 'aangaangde', 'op', 'tamelijk', 'zekere', 'voordien', 'precies', 'kan', 'geleden', '€', 'daarom', 'later', 'hierbeneden', 'meesten', 'rond', 'gegeven', 'ook', 'hoewel', 'te', 'volgens', 'steeds', 'wiens', 'mijn', 'inz', 'kon', 'kunt', 'nabij', 'omstreeks', 'publ', 'werden', 'konden', 'meer', "'t", 'gehad', 'x', 'effe', 'jezelf', 'beide', 'gekund', 'dezen', 'eveneens', 'geven', 'klaar', 'naar', 'vooruit', 'geworden', 'gij', 'allebei', 'heb', 'tegen', 'm', 'eerste', 'zich', 'ooit', 'mij', 'jouw', 'dikwijls', 'elk', 'zou', 'een', 'rondom', 'doet', 'wier', 'andere', 'veel', 'zoals', 'dit', 'm³.', 'gemogen', 'wanneer', 'tenzij', 'bij', 'anders', 'daarheen', 'ons', 'en', 'opdat', 'had', 'mijzelf', 'voordat', 'alhoewel', 'worden', 'des', 'weinige', 'moet', 'jij', 'net', 'reeds', 'voorop', 'binnen', 'behalve', 'mezelf', 'enige', '1e', 'afm', 'waren', 'mede', 'uit', 'hun', 'ten', 'vaak', 'gewoon', 'die', 'krachtens', 'bepaald', 'allen', 'altijd', 'misschien', 'doorgaand', 'aldus', 'twee', 'totaal', 'eigen', 'je', 'beneden', 'deze', 'zeker', 'vooralsnog', 'ben', 'achter', 'sedert', '+', 'daarin', 'opzij', 'wat', 'iets', 'voor', 'moesten', 'gelijk', 'omhoog', 'vrij', 'pp', 'zulke', 'toch', 'veeleer', 'beiden', 'dat', 'hare', 'omdat', 'waarom', 'vanaf', 'mogelijk', 'tussen', 'af', 'verder', 'ongeveer', 'maar', 'eens', 'nr', 'met', 'II', 'welk', 'moeten', 'mocht', 'wij', 'men', 'ter', 'hem', 'eerst', 'zijnde', 'wegens', 'ik', 'achterna', 'hebben', 'erdoor', 'voorbij', 'zijn', 'min', 'dien', 'hier', '±', 'zei', 'dezelfde', 'zelfs', 'anderen', 'iemand', 'niet', 'voort', 'slechts', 'idd', 'uwe', '‘t', 'vandaan', 'bent', 'betreffende', 'het', 'zult', 'mogen', '2e', 'voorheen', 'onder', 'zulk', 'inzake', 'wel', 'indien', 'dan', 'totdat', 'vgl', 'voorts', 'vooraf', 'hen', 'ja', 'vind', 'geen', 'vroeg', 'nadat', 'omtrent', 'nooit', 'circa', 'liever', 'vanwege', 'spoedig', 'weinig', 'zeer', 'dus', 'vervolgens', 'werd', 'nu', 'van', 'omlaag', 'zij', 'wie', 'uwen', 'echter', 'geheel', 'moest', 'onszelf', 'om', 'opnieuw', 'den', 'ff', 'was', 'binnenin', 'hadden', 'verre', 'jou', 'onze', 'heeft', 'daarna', 'bovenal', 'evenwel', 'even', 'tot', 'etc', 'doen', 'de'}

# %%
# Check if string is composed of digits and punctuations only
digit_re = re.compile('^([0-9]|[\\.,])*$€')

# %%
# Cleaning tokens
tokens_cleaned = []
for doc in docs:
    new_tokens = []
    for token in doc:
        if not token.is_stop and not token.is_punct and not re.match(digit_re, token.text):
            new_tokens.append(token.text)
    tokens_cleaned.append(new_tokens)

# %%
tokens_cleaned[0:5]
# Out:
# [['Ruimte',
#   'vrijheid',
#   'water',
#   'weides',
#   'heen',
#   'tikkeltje',
#   'romantiek',
#   'nostalgie',
#   'voortdurende',
#   'vakantiegevoel',
#   'rust',
#   'leven',
#   'woonark',
#   'nét',
#   'ark',
#   'voelt',
#   'echt',
#   'wonen',
#   'Stilletjes',
#   'deinend',
#   'kabbelend',
#   'water',
#   'zwemmende',
#   'eendjes',
#   'bieden',
#   'kans',
#   'gaan',
#   'ervaren',
#   ' ',
#   'Algemeen',
#   'Rustig',
#   'gelegen',
#   'breed',
#   'vaarwater',
#   'dorp',
#   'supermarkt',
#   'snackbar',
#   'café-restaurant',
#   'Landelijke',
#   'omgeving',
#   'Omsloten',
#   'tuin',
#   '300',
#   'm2',
#   'berging',
#   'zuidoosten',
#   'gebruiksvergoeding',
#   'gemeente',
#   'Ligplaatscanon',
#   'via',
#   'Hollands',
#   'Noorderkwartier',
#   'Garage',
#   'parkeerruimte',
#   'wegzijde',
#   ' ',
#   'Omschrijving',
#   'gelijkvloers',
#   'charmante',
#   'woonark',
#   'tuin',
#   'stapt',
#   'loopbrug',
#   'ark',
#   'ervaart',
#   'direct',
#   'bijzondere',
#   'sfeer',
#   'wonen',
#   'water',
#   'corridor',
#   'loopt',
#   'gehele',
#   'lengte',
#   'ark',
#   'Links',
#   'knusse',
#   'woonkamer',
#   'daarachter',
#   'keuken',
#   'koelkast',
#   'wasemkap',
#   'elektrische',
#   'kookplaat',
#   'bijkeuken',
#   'ernaast',
#   'voldoende',
#   'ruimte',
#   'vriezer',
#   'magnetron',
#   'oven',
#   'deur',
#   'zodat',
#   'omloop',
#   'kanten',
#   'schitterende',
#   'uitzicht',
#   'genieten',
#   ' ',
#   'woongedeelte',
#   'heerlijk',
#   'vertoeven',
#   'uitzicht',
#   'water',
#   'ene',
#   'kant',
#   'mooie',
#   'tuin',
#   'kant',
#   ' ',
#   'Doordat',
#   'vensters',
#   'kanten',
#   'ark',
#   'lichtinval',
#   'optimaal',
#   'ramen',
#   'woonkamer',
#   'geïsoleerd',
#   'zonwerende',
#   'folie',
#   'zodat',
#   'té',
#   'warm',
#   'ark',
#   'ruimte',
#   'slim',
#   'gebruikt',
#   'vouwdeuren',
#   'plaatsen',
#   'ouderslaapkamer',
#   'kleine',
#   'slaapkamer',
#   'badkamer',
#   'bereikbaar',
#   'via',
#   'corridor',
#   'kunststof',
#   'kozijnen',
#   'ramen',
#   'kleine',
#   'luxe',
#   'badkamer',
#   'bevindt',
#   'toilet',
#   'wastafel',
#   'heerlijke',
#   'stoomcabine',
#   'Achterin',
#   'corridor',
#   'cv-ruimte',
#   'tevens',
#   'aansluiting',
#   'wasmachine',
#   'droger',
#   'zit',
#   ' ',
#   'heerlijke',
#   'tuin',
#   'biedt',
#   'privacy',
#   'doordat',
#   'perceel',
#   'volledig',
#   'omheind',
#   'tuinhuis',
#   'recentelijk',
#   'geïsoleerd',
#   'voorzien',
#   'elektra',
#   'mogelijkheden',
#   'eindeloos',
#   'extra',
#   'slaap',
#   'kamer',
#   'man',
#   'cave',
#   'bed',
#   'breakfast',
#   'Laat',
#   'fantasie',
#   'los',
#   'kijk',
#   'allemaal',
#   ' ',
#   'Uzelf',
#   'heerlijke',
#   'tuin',
#   'ark',
#   'water',
#   'mooi',
#   'leven',
#   'woonark',
#   'bevestigd',
#   'Kom',
#   'sfeer',
#   'proeven',
#   'voel',
#   'vrijheid',
#   ' ',
#   'collegiale',
#   'verkoop',
#   'Zuurbier',
#   'Makelaardij',
#   ' ',
#   'www.zuurbiermakelaardij.nl',
#   '06',
#   '5339',
#   '3945'],
#  ['Verrassend',
#   'ruime',
#   'tussenwoning',
#   'centrum',
#   ' ',
#   'lijkt',
#   'gewone',
#   'tussenwoning',
#   'Schijn',
#   'bedriegt',
#   'eenmaal',
#   'ontdek',
#   'verrassend',
#   'ruimte',
#   'dachten',
#   'huis',
#   'twintig',
#   'jaar',
#   'zagen',
#   'vertellen',
#   'huidige',
#   'bewoners',
#   'Privacy',
#   'zowel',
#   'vóór',
#   'zitten',
#   'etalage',
#   'ligging',
#   'hartje',
#   'Haaksbergen',
#   'winkels',
#   'dichtbij',
#   'tegelijkertijd',
#   'rust',
#   'eind',
#   'doodlopend',
#   'straatje',
#   'gaf',
#   'destijds',
#   'doorslag',
#   'gaan',
#   'wonen',
#   ' ',
#   'Buurt',
#   ' ',
#   'straatkant',
#   'huis',
#   'aangebouwde',
#   'stenen',
#   'berging',
#   'bereikbaar',
#   'hal',
#   'dakkapel',
#   'ramen',
#   'kozijnen',
#   'buitendeuren',
#   'berging',
#   'kunststof',
#   'Beweegbare',
#   'ramen',
#   'draaikiep',
#   'oprit',
#   'voldoende',
#   'parkeerplekken',
#   'directe',
#   'omgeving',
#   'overzijde',
#   'straat',
#   'ligt',
#   'groot',
#   'groen',
#   'openbaar',
#   'terrein',
#   'gevoel',
#   'ruimte',
#   'vrijheid',
#   'schept',
#   'ingericht',
#   'leuke',
#   'speelvoorzieningen',
#   'kinderen',
#   'buurt',
#   'fijne',
#   'buurt',
#   'trouwens',
#   'bewoners',
#   'uur',
#   'ziet',
#   'verjonging',
#   'buurtfeest',
#   'buurtapp',
#   'elkaar',
#   'seinen',
#   'verdachts',
#   'zien',
#   '  ',
#   'Woonkeuken',
#   ' ',
#   'stel',
#   '2006',
#   'achtergevel',
#   '’n',
#   'tweeënhalve',
#   'meter',
#   'uitgebouwd',
#   'muur',
#   'keuken',
#   'woonkamer',
#   'achteren',
#   'opgeschoven',
#   'ingreep',
#   'royale',
#   'living',
#   'opgeleverd',
#   'én',
#   'straatzijde',
#   'mooie',
#   'woonkeuken',
#   'goeie',
#   'investering',
#   'plezier',
#   'woonkeuken',
#   'geliefde',
#   'plek',
#   'zitten',
#   'keuken',
#   'strak',
#   'modern',
#   'uitgevoerd',
#   'hoogglans',
#   'vanille',
#   'fraaie',
#   'kookschiereiland',
#   'zwart',
#   'gemêleerd',
#   'extra',
#   'dik',
#   'werkblad',
#   'graniet',
#   'Siemens',
#   'inbouwapparatuur',
#   'waaronder',
#   'koffiemachine',
#   'oven/magnetron',
#   'symmetrisch',
#   'geïntegreerd',
#   'wand',
#   ' ',
#   'Royale',
#   'living',
#   'living',
#   'royaal',
#   'licht',
#   'glasrijk',
#   'strakke',
#   'schouw',
#   'afstand',
#   'bedienbare',
#   'én',
#   'programmeerbare',
#   'gas',
#   'designhaard',
#   '’s',
#   'avonds',
#   'frisjes',
#   'geeft',
#   'snel',
#   'behaaglijke',
#   'warmte',
#   'XL',
#   'schuifpui',
#   'verbindt',
#   'living',
#   'omsloten',
#   'onderhoudsarme',
#   'achtertuin',
#   'achtergrens',
#   'kavel',
#   'knusse',
#   'overkapping',
#   'gebouwd',
#   'Terug',
#   'hal',
#   'woonkeuken',
#   'living',
#   'ligt',
#   'grijze',
#   'pvc',
#   'vloer',
#   'houtlook',
#   'keurige',
#   'toiletruimte',
#   'provisiekast',
#   'trap',
#   ' ',
#   'Slapen',
#   'baden',
#   'verdieping',
#   'telt',
#   'drie',
#   'slaapkamers',
#   ' ',
#   'ervan',
#   'kun',
#   'gerust',
#   'ruim',
#   'noemen',
#   'Nummer',
#   'drie',
#   'kleiner',
#   'prima',
#   'grote',
#   'inloopkast',
#   'gemaakt',
#   'badkamer',
#   'drie',
#   'jaar',
#   'terug',
#   'helemaal',
#   'tijd',
#   'gebracht',
#   'inloopdouche',
#   'glaswand',
#   'ligbad',
#   'zwevend',
#   'toilet',
#   'extra',
#   'brede',
#   'wastafel',
#   'meubel',
#   'designradiator',
#   'donkergrijze',
#   'tegelvloer',
#   'verwarmd',
#   'combineert',
#   'mooi',
#   'witte',
#   'sanitair',
#   'overloop',
#   'grenst',
#   'vaste',
#   'kast',
#   'separate',
#   'waskamer',
#   'wasautomaat',
#   'staat',
#   'echt',
#   'handig',
#   'zolder',
#   'bereikbaar',
#   'via',
#   'vaste',
#   'trap',
#   'bevindt',
#   'slaapvertrek',
#   'nummer',
#   'vier',
#   'onderhoudsarme',
#   'dakkapel',
#   'schept',
#   'ruimte',
#   'zolder',
#   'mooi',
#   'voorportaal',
#   'extra',
#   'bergruimte',
#   '  ',
#   'Bijzonderheden',
#   'bouwjaar',
#   '1980',
#   'perceeloppervlakte',
#   '148',
#   'inhoud',
#   '481',
#   ' ',
#   'Groottes',
#   'oppervlaktes',
#   'berekend',
#   'extern',
#   'buro',
#   'gebaseerd',
#   'NEN',
#   '2580',
#   'koopakte',
#   '10%',
#   'waarborgsom',
#   'bankgarantie',
#   'opgenomen'],
#  ['ENGLISH',
#   'TRANSLATION',
#   '  ',
#   'On',
#   'the',
#   '21st',
#   'September',
#   'you',
#   'will',
#   'be',
#   'able',
#   'to',
#   'place',
#   'your',
#   'bid',
#   'online',
#   'during',
#   'the',
#   'auction',
#   'time',
#   'as',
#   'mentioned',
#   'below',
#   'Bidding',
#   'starts',
#   'on',
#   '21st',
#   'September',
#   '2018',
#   'at',
#   '3PM',
#   ' ',
#   'Bidding',
#   'closes',
#   'on',
#   '21st',
#   'September',
#   '2018',
#   'at',
#   '7PM',
#   ' ',
#   'Viewings',
#   'can',
#   'be',
#   'arranged',
#   'via',
#   'the',
#   'realtor',
#   'as',
#   'mentioned',
#   'on',
#   'Bieden',
#   'Wonen',
#   'Please',
#   'notice',
#   'that',
#   'you',
#   'will',
#   'need',
#   'to',
#   'register',
#   'yourself',
#   'as',
#   'a',
#   'bidder',
#   'first',
#   'via',
#   'website',
#   'Bieden',
#   'Wonen',
#   '  ',
#   'DUTCH',
#   'TRANSLATION',
#   '  ',
#   '21',
#   'september',
#   '2018',
#   'meebieden',
#   'getoonde',
#   'vanafprijs',
#   'veilingtijd',
#   'afloopt',
#   'Biedtermijn',
#   'start',
#   '21',
#   'september',
#   '2018',
#   '15:00',
#   'uur',
#   ' ',
#   'Biedtermijn',
#   'sluit',
#   '21',
#   'september',
#   '2018',
#   '19:00',
#   'uur',
#   '  ',
#   'Bezichtigingen',
#   'via',
#   'Bieden',
#   'Wonen',
#   'site',
#   'geregeld',
#   'makelaar',
#   'Houd',
#   'rekening',
#   'mee',
#   'registreren',
#   'bieder',
#   'via',
#   'website',
#   'Bieden',
#   'Wonen',
#   ' ',
#   'GROUNDLEASE',
#   'There',
#   'a',
#   'ground',
#   'lease',
#   'which',
#   'around',
#   '1.000',
#   'per',
#   'year',
#   '  ',
#   'DUTCH',
#   'INFORMATION',
#   '  ',
#   'mooie',
#   '3-kamerappartement',
#   'maakt',
#   'deel',
#   'luxe',
#   'kleinschalig',
#   'complex',
#   'complex',
#   'maakt',
#   'deel',
#   'groene',
#   'ruim',
#   'opgezette',
#   'CalandparC',
#   'project',
#   'bestaat',
#   ' ',
#   'eengezinswoningen',
#   'urban',
#   'villa',
#   '’s',
#   'onderverdeeld',
#   '16',
#   'appartementen',
#   'garageplekken',
#   ' ',
#   'Via',
#   'ruime',
#   'lichte',
#   'verzorgde',
#   'entree',
#   'toegang',
#   'lift',
#   'gemeenschappelijk',
#   'trappenhuis',
#   'appartement',
#   'ruim',
#   '69m2',
#   'gelegen',
#   'derde',
#   'verdieping',
#   'living',
#   'open',
#   'keuken',
#   'schuifpui',
#   'balkon',
#   'ramen',
#   'grond',
#   'zorgt',
#   'extra',
#   'lichtinval',
#   'mooi',
#   'uitzicht',
#   'grootte',
#   'variërende',
#   'slaap',
#   'kamers',
#   'zijkant',
#   'gelegen',
#   'Interne',
#   'ruimte',
#   'wasmachine-',
#   'drogeraansluiting',
#   'extra',
#   'bergruimte',
#   'Apart',
#   'ruim',
#   'toilet',
#   'nette',
#   'badkamer',
#   'bad/douche',
#   'gehele',
#   'appartement',
#   'voorzien',
#   'kwalitatief',
#   'goede',
#   'laminaatvloer',
#   'onderbouw',
#   'parkeerplaatsen',
#   'gelegen',
#   'veilig',
#   'afgesloten',
#   'elektrische',
#   'garagedeur',
#   ' ',
#   'Gunstig',
#   'VvE',
#   'gezond',
#   'actief',
#   ' ',
#   'ERFPACHT',
#   'erfpacht',
#   'afgekocht',
#   'bedraagt',
#   '1.000',
#   'per',
#   'jaar',
#   '  ',
#   'OMGEVING',
#   ' ',
#   'Osdorpplein',
#   'loopafstand',
#   'gelegen',
#   'biedt',
#   'ruime',
#   'keuze',
#   'winkels',
#   'Tal',
#   'recreatie',
#   'voorzieningen',
#   'loop-/',
#   'fietsafstand',
#   'natuurpark',
#   'Vrije',
#   'Geer',
#   'Sloterpark',
#   'uiteraard',
#   'vergeten',
#   'Nieuwe',
#   'Daarnaast',
#   'goede',
#   'tram',
#   '1',
#   '17',
#   'busverbindingen',
#   'waarmee',
#   'afzienbare',
#   'tijd',
#   'binnenstad',
#   'bereikt',
#   'uitvalswegen',
#   'A',
#   '4',
#   'A5',
#   'A9',
#   'A10'],
#  ['Wonen',
#   'royaal',
#   'bemeten',
#   'geschakelde',
#   '2-onder-1-kapwoning',
#   'garage',
#   'fijne',
#   'woning',
#   'voorzien',
#   'sfeervolle',
#   'woonkamer',
#   '4',
#   'slaapkamers',
#   'luxueuze',
#   'badkamer',
#   'fijne',
#   'achtertuin',
#   '15',
#   'm',
#   'diep',
#   'Gelegen',
#   'prima',
#   'woonomgeving',
#   'Woenselse',
#   'Heide',
#   'winkels',
#   'scholen',
#   'Henri',
#   'Dunant',
#   'park',
#   'sportaccommodaties',
#   'uitvalswegen',
#   ' ',
#   'Indeling',
#   'begane',
#   'grond',
#   'Hal',
#   'voorzien',
#   'tegelvloer',
#   'meterkast',
#   '7',
#   'groepen',
#   '1',
#   'aardlekschakelaar',
#   'garderobe',
#   'nis',
#   'keurig',
#   'betegeld',
#   'toilet',
#   'fontein',
#   'toegang',
#   'woonkamer',
#   'trapopgang',
#   ' ',
#   'verdieping',
#   ' ',
#   'Sfeervolle',
#   'royale',
#   'woonkamer',
#   'prettige',
#   'lichtinval',
#   'voorzien',
#   'tegelvloer',
#   'sierpleister',
#   'wanden',
#   'trapkast',
#   'glasvezelaansluiting',
#   'elektrisch',
#   'bedienbaar',
#   'rolluik',
#   'achterzijde',
#   ' ',
#   'Semi',
#   'open',
#   'keuken',
#   'voorzien',
#   'L-vormige',
#   'keukeninrichting',
#   'diverse',
#   'onder-',
#   'bovenkasten',
#   '1½',
#   'RVS',
#   'spoelbak',
#   'gaskookplaat',
#   'oven',
#   'afzuigkap',
#   'koelkast',
#   'vaatwasser',
#   'elektrisch',
#   'bedienbaar',
#   'rolluik',
#   'toegang',
#   'achtertuin',
#   ' ',
#   'Garage',
#   'ca.',
#   '8.00',
#   'm',
#   'x',
#   '3.07',
#   'm',
#   'voorzien',
#   'stalen',
#   'kanteldeur',
#   'verlichting',
#   'elektra',
#   '  ',
#   'Indeling',
#   'verdieping',
#   'Overloop',
#   'voorzien',
#   'tapijt',
#   'toegang',
#   '3',
#   'slaapkamers',
#   'badkamer',
#   'trapopgang',
#   ' ',
#   'verdieping',
#   '  ',
#   'Royale',
#   'slaapkamer',
#   'ca.',
#   '3.68',
#   'm',
#   'x',
#   '3.94',
#   'm',
#   'voorzien',
#   'tapijt',
#   'wastafel',
#   'toegang',
#   'balkon',
#   ' ',
#   'Slaapkamer',
#   'ca.',
#   '3.09',
#   'm',
#   'x',
#   '2.91',
#   'm',
#   'voorzien',
#   'tapijt',
#   'sierpleister',
#   'wanden',
#   ' ',
#   'Royale',
#   'slaapkamer',
#   'ca.',
#   '4.31',
#   'm',
#   'x',
#   '3.58',
#   'm',
#   'voorzien',
#   'tapijt',
#   'sierpleister',
#   'wanden',
#   ' ',
#   'Luxueuze',
#   '2015',
#   'gemoderniseerde',
#   'betegelde',
#   'badkamer',
#   'voorzien',
#   'inloopdouche',
#   'thermostaatkraan',
#   'badkamermeubel',
#   '2',
#   'wastafels',
#   'wandcloset',
#   'design',
#   'radiator',
#   'wasmachine',
#   'aansluiting',
#   'vernieuwd',
#   'kozijn',
#   'plafond',
#   'inbouwspots',
#   ' ',
#   'Indeling',
#   'verdieping',
#   'Via',
#   'vaste',
#   'trap',
#   'bereikbare',
#   'voorzolder',
#   'voorzien',
#   'tapijt',
#   'kunststof',
#   'uitgevoerd',
#   'dakvenster',
#   'wasmachine',
#   'aansluiting',
#   'bergruimte',
#   'c.v.-combiketel',
#   'bouwjaar',
#   'ca.',
#   '2010',
#   'toegang',
#   'slaapkamer',
#   ' ',
#   'Royale',
#   'slaapkamer',
#   'ca.',
#   '4.90',
#   'm',
#   'x',
#   '3.98',
#   'm',
#   'voorzien',
#   'tapijt',
#   '2',
#   'kunststof',
#   'uitgevoerde',
#   'dakvensters',
#   'bergruimte',
#   '  ',
#   'Tuin',
#   'Keurig',
#   'aangelegde',
#   'voortuin',
#   'gevarieerde',
#   'beplanting',
#   'ruime',
#   'oprit',
#   '  ',
#   'Fijne',
#   'goed',
#   'verzorgde',
#   'zonnige',
#   'achtertuin',
#   'ca.',
#   '15',
#   'm',
#   'diep',
#   'voorzien',
#   'sierbestrating',
#   'gazon',
#   ' ',
#   'borders',
#   'gevarieerde',
#   'beplanting',
#   'verlichting',
#   'poort',
#   'toegang',
#   'garage',
#   '  ',
#   'Bijzonderheden',
#   'betreft',
#   'royale',
#   'geschakelde',
#   '2-onder-1-kapwoning',
#   'garage',
#   'NEN',
#   '2580',
#   'maatrapport',
#   'woning',
#   'gemaakt',
#   'Rechter',
#   'buitengevel',
#   '2014',
#   'geïsoleerd',
#   'Sfeervolle',
#   'woonkamer',
#   'prettige',
#   'lichtinval',
#   ' ',
#   '4',
#   'prima',
#   'slaapkamers',
#   'Luxueuze',
#   '2015',
#   'gemoderniseerde',
#   'badkamer',
#   'Royale',
#   'oprit',
#   'Fijne',
#   'zonnig',
#   'gelegen',
#   'achtertuin',
#   'ca.',
#   '15',
#   'm',
#   'diep',
#   ' ',
#   'Gelegen',
#   'prima',
#   'locatie',
#   'gewilde',
#   'woonomgeving',
#   'Woenselse',
#   'Heide',
#   ' ',
#   'Henri',
#   'Dunant',
#   'park',
#   'winkels',
#   'scholen',
#   'sportaccommodaties',
#   ' ',
#   'uitvalswegen',
#   'Kom',
#   'vrijblijvend',
#   'kijken',
#   'ervaar',
#   'fijne',
#   'ligging',
#   'prima',
#   'ruimtes',
#   'woning',
#   'biedt',
#   'Bel',
#   '    ',
#   'mail',
#   'bezichtiging',
#   ' ',
#   'zekerheid',
#   'nakoming',
#   'verplichtingen',
#   'koper',
#   'dient',
#   'koper',
#   '7',
#   'weken',
#   'mondelinge',
#   'overeenkomst',
#   'waarborgsom',
#   'grootte',
#   '10%',
#   'koopsom',
#   'storten',
#   'rekening',
#   'notaris',
#   'plaats',
#   'hiervan',
#   'bankgarantie',
#   'gesteld',
#   'grootte',
#   'bedrag',
#   'geldverstrekker',
#   'verzorgen',
#   ' ',
#   'Meetinstructie',
#   'gebaseerd',
#   'NEN2580',
#   'Meetinstructie',
#   'bedoeld',
#   'eenduidige',
#   'manier',
#   'meten',
#   'passen',
#   'indicatie',
#   'gebruiksoppervlakte',
#   'Meetinstructie',
#   'sluit',
#   'verschillen',
#   'meetuitkomsten',
#   'volledig',
#   'interpretatieverschillen',
#   'afrondingen',
#   'beperkingen',
#   'uitvoeren',
#   'meting'],
#  ['Landgoed',
#   'Junne',
#   'eeuwenoud',
#   'landgoed',
#   'ligt',
#   'fenomenaal',
#   'bocht',
#   'rivier',
#   'Vecht',
#   'landgoed',
#   '1047',
#   'hectare',
#   'groot',
#   'markante',
#   'plek',
#   'kern',
#   'landgoed',
#   'woonboerderij',
#   'Hermink',
#   'inhoud',
#   '1246',
#   'aangeboden',
#   'grote',
#   'vrijstaande',
#   'schuur',
#   'opp',
#   '99',
#   'kapschuur',
#   'opp',
#   '35',
#   'kookhuisje',
#   'opp',
#   '8',
#   'kavel',
#   '4500',
#   'vraagprijs',
#   'opstallen',
#   'bedraagt',
#   '257.500,-',
#   'k.k.',
#   'grond',
#   'erfpacht',
#   'uitgegeven',
#   'fiscaal',
#   'aftrekbare',
#   'canon',
#   'bedraagt',
#   '9500,-',
#   'per',
#   'jaar',
#   'woonboerderij',
#   'juiste',
#   'prijsklasse',
#   'internet',
#   'tonen',
#   'grondcomponent',
#   'bedrag',
#   '237.500,-',
#   'opgenomen',
#   'vraagprijs',
#   '495.000,-',
#   'k.k.',
#   'Uiteraard',
#   'grondcomponent',
#   'mindering',
#   'gebracht',
#   'vraagprijs',
#   '495.000,-',
#   'k.k.',
#   'verkoop',
#   'opstallen',
#   'WoningSchouw',
#   'Eefde',
#   'woonboerderij',
#   'recent',
#   'bouwtechnisch',
#   'gekeurd',
#   'keuringsrapport',
#   'opgenomen',
#   'verkoopbrochure',
#   'woonboerderij',
#   'energielabel',
#   'D.',
#   'bodemonderzoeksrapport',
#   'asbestinventarisatierapport',
#   'eerdaags',
#   'overhandigd',
#   'alsmede',
#   'offerte',
#   'bestrijden',
#   'houtparasieten',
#   'vorige',
#   'bewoners',
#   'verzorgden',
#   'natuureducatie',
#   'locatie',
#   'ziet',
#   'terug',
#   'inrichting',
#   'woonboerderij',
#   'uitgifte',
#   'erfpacht',
#   'voorbehoud',
#   'gunning',
#   'grondeigenaar',
#   ' ',
#   'Indeling',
#   'woonboerderij',
#   'Begane',
#   'grond',
#   'entree',
#   'meterkast',
#   'hal',
#   'trapopgang',
#   'verdieping',
#   'keuken',
#   'diepe',
#   'inloopkast',
#   'hoekaanrechtblok',
#   'voorzien',
#   'inbouwapparatuur',
#   'keramische',
#   'kookplaat',
#   'magnetron',
#   'vaatwasser',
#   'koelkast',
#   'afzuigkap',
#   'woonkamer',
#   'schouw',
#   'werkkamer',
#   'vaste',
#   'kast',
#   'badkamer',
#   'bubbelbad',
#   'doucheruimte',
#   'wastafels',
#   'separate',
#   'toiletruimte',
#   'wandcloset',
#   'wastafel',
#   'grote',
#   'slaapkamer',
#   'kastenwand',
#   'slaapkamers',
#   'werkkamer',
#   'betegelde',
#   'wasruimte',
#   'inpandige',
#   'berging',
#   'houten',
#   'deuren',
#   'trapopgang',
#   'grote',
#   'zolderruimte',
#   'doucheruimte',
#   'wandcloset',
#   'wastafel',
#   'portaal/gangetje',
#   ' ',
#   'Verdieping',
#   'overloop',
#   'luikje',
#   'vliering',
#   'slaapkamers',
#   'waarvan',
#   'één',
#   'slaapkamer',
#   'vaste',
#   'kast',
#   'ketelruimte',
#   'toiletruimte',
#   'wandcloset',
#   'wastafel',
#   ' ',
#   'Bijgebouwen',
#   'grote',
#   'vrijstaande',
#   'schuur',
#   'afmetingen',
#   '10.20',
#   'x',
#   '9.70',
#   'meter',
#   'opgetrokken',
#   'steen',
#   'zadeldak',
#   'gedekt',
#   'keramische',
#   'dakpannen',
#   'schuur',
#   'bestaat',
#   'kleine',
#   'ruimte',
#   'aanrechtblokje',
#   'trap',
#   'grote',
#   'zolderruimte',
#   'deel',
#   'houten',
#   'deuren',
#   'kapschuur',
#   'afmetingen',
#   '5.60',
#   'x',
#   '6.30',
#   'meter',
#   'opgetrokken',
#   'hout',
#   'stenen',
#   'voet',
#   'kap',
#   'gedekt',
#   'keramische',
#   'dakpannen',
#   'kookhuisje',
#   'afmetingen',
#   '2.50',
#   'x',
#   '3.00',
#   'meter',
#   'opgetrokken',
#   'steen',
#   'hout',
#   'kap',
#   'gedekt',
#   'keramische',
#   'dakpannen',
#   'Bestemming',
#   'perceel',
#   'vigerende',
#   'bestemmingsplan',
#   'bestemming',
#   'woondoeleinden',
#   'dubbelbestemming',
#   'agrarisch',
#   'gebied',
#   'landschappelijke',
#   'waarden',
#   'aanduiding',
#   'voormalig',
#   'agrarisch',
#   'bedrijf',
#   'bestemmingsplankaart',
#   'voorschriften',
#   'toegevoegd',
#   'verkoopbrochure']]

# %%
# Pass dummy function to the tokenizer and preprocessor parameters of count vectorizer because we already calculated our tokens
def dummy(doc):
    return doc

count_vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
)

frequency_matrix = count_vectorizer.fit_transform(tokens_cleaned)

# %%
type(frequency_matrix)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
count_vectorizer.get_feature_names()[:50]
# Out:
# [' ',
#  '  ',
#  '   ',
#  '    ',
#  '     ',
#  '      ',
#  '       ',
#  '        ',
#  '         ',
#  '          ',
#  '           ',
#  '            ',
#  '             ',
#  '              ',
#  '               ',
#  '                ',
#  '                 ',
#  '                  ',
#  '                   ',
#  '                    ',
#  '                     ',
#  '                      ',
#  '                       ',
#  '                        ',
#  '                         ',
#  '                          ',
#  '                           ',
#  '                            ',
#  '                             ',
#  '                              ',
#  '                               ',
#  '                                ',
#  '                                 ',
#  '                                  ',
#  '                                   ',
#  '                                    ',
#  '                                     ',
#  '                                      ',
#  '                                       ',
#  '                                        ',
#  '                                         ',
#  '                                          ',
#  '                                           ',
#  '                                            ',
#  '                                             ',
#  '                                              ',
#  '                                               ',
#  '                                                ',
#  '                                                 ',
#  '                                                  ']

# %%
count_vectorizer.get_feature_names()[-2000:-1950]
# Out:
# ['~2.6',
#  '~45',
#  '~5m2',
#  '~ACHTERTUIN~',
#  '~ALGEMEEN~',
#  '~Algemeen~',
#  '~BEGANE',
#  '~BEREIKBAARHEID~',
#  '~BESTEMMINGSPLAN~',
#  '~BIEDEN',
#  '~BIEDING~',
#  '~BIJZONDERHEDEN~',
#  '~CIRCA',
#  '~CONCEPT~',
#  '~Carport',
#  '~Circa',
#  '~EERSTE',
#  '~ERFPACHT~',
#  '~EXCLUSIEF',
#  '~GARAGE',
#  '~Het',
#  '~INDELING',
#  '~INDELING~',
#  '~INSCHRIJVING~',
#  '~INTERESSE~',
#  '~Indeling~',
#  '~KELDER~',
#  '~KENMERKEN',
#  '~KENMERKEN~',
#  '~Kenmerken~',
#  '~LOCATIE~',
#  '~Let',
#  '~OMGEVING~',
#  '~OMSCHRIJVING~',
#  '~OUD-BEIJERLAND~',
#  '~TUIN',
#  '~TUIN~',
#  '~TWEEDE',
#  '~Unieke',
#  '~VERENIGING',
#  '~VERKOOP',
#  '~VERKOPER',
#  '~VOOR',
#  '~Voldoende',
#  '~W96~',
#  '~WONINGEN~',
#  '~Zeer',
#  '~Zonnige',
#  '~circa',
#  '~praktische']

# %%
count_vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    max_features=4000
    )
frequency_matrix = count_vectorizer.fit_transform(tokens_cleaned)

# %%
frequency_matrix
# Out:
# <210876x4000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 28484925 stored elements in Compressed Sparse Row format>

# %%
tfd_idf_trans = TfidfTransformer()
tf_idf_matrix = tfd_idf_trans.fit_transform(frequency_matrix)

# %%
tf_idf_matrix
# Out:
# <210876x4000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28484925 stored elements in Compressed Sparse Row format>

# %%
# We use 10 as the number of topics
model = NMF(n_components=10, init='nndsvd')

# fit the model
model.fit(X=tf_idf_matrix)
# Out:
# NMF(init='nndsvd', n_components=10)

# %%
# Mapping topics to word weights
model.components_
model.components_.shape
# Out:
# array([[9.56644930e+00, 4.03425559e-01, 3.55140527e-01, ...,
#         0.00000000e+00, 1.92191911e-04, 1.82176111e-02],
#        [3.77235428e-01, 1.32939737e-01, 3.02086517e-02, ...,
#         1.14132479e-04, 2.99144572e-02, 6.29285620e-03],
#        [4.70902580e-01, 1.64922745e-01, 8.00490971e-02, ...,
#         0.00000000e+00, 8.28938604e-03, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 1.76978905e+00, 4.26276435e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 6.28252889e-03],
#        [1.63971754e+00, 1.38873761e+00, 1.85070853e-01, ...,
#         1.54773412e-01, 3.40044983e-01, 3.95944787e-02],
#        [7.14118377e-01, 6.25196620e-01, 1.74775697e-01, ...,
#         0.00000000e+00, 2.51136950e-01, 0.00000000e+00]])
# (10, 4000)

# %%
def get_topics(model, n_top_words):

    feature_names = count_vectorizer.get_feature_names()
    d = {}
    for i in range(model.n_components):
        words_ids = model.components_[i].argsort()[:-20 -1:-1]
        words = [feature_names[key] for key in words_ids]
        d['Topic # ' + '{:02d}'.format(i+1)] = words
    return pd.DataFrame(d)

# %%
get_topics(model, 10)
# Out:
#          Topic # 01 Topic # 02   Topic # 03            Topic # 04  \
# 0                          the            x           appartement
# 1                 3        and            m                balkon
# 2          Bouwjaar       with   Slaapkamer               complex
# 3            toilet          a           m.                   per
# 4                 2        The                              maand
# 5                           to         3.00               gelegen
# 6                 1      floor     voorzien                  lift
# 7            Inhoud         on    Woonkamer              uitzicht
# 8          Badkamer       room            2              voorzien
# 9             grond  apartment     Badkamer               berging
# 10           Begane        you         4.00               toegang
# 11       Slaapkamer        has  achterzijde         parkeerplaats
# 12          overleg        for            1
# 13       informatie        are         2.00  appartementencomplex
# 14                          at      toegang             woonkamer
# 15         Overloop      house                             entree
# 16           douche   spacious     afmeting                   hal
# 17  Woonoppervlakte    kitchen           II                keuken
# 18       Verdieping    located     kozijnen             onderbouw
# 19      Aanvaarding                      ca           trappenhuis
#
#        Topic # 05                Topic # 06           Topic # 07  \
# 0        woningen            Meetinstructie                  ca.
# 1   appartementen              particuliere                   m2
# 2            type                   NEN2580                   m.
# 3              m2          koopovereenkomst                  v.v
# 4            fase               verschillen                    x
# 5           wonen                     meten           Slaapkamer
# 6       standaard                  verkoper             Bouwjaar
# 7    hoekwoningen                    meting               Inhoud
# 8                       gebruiksoppervlakte      Woonoppervlakte
# 9         project               afrondingen                    6
# 10           plan  interpretatieverschillen                   10
# 11       sanitair            meetuitkomsten                   12
# 12           Type               beperkingen  NVM-aankoopmakelaar
# 13  verschillende                     koper                    8
# 14          meter                   bedoeld                    9
# 15           wijk                eenduidige                   11
# 16   zonnepanelen                 indicatie                    7
# 17         woning                 uitvoeren                   m3
# 18        verkoop                    manier      woonoppervlakte
# 19   architectuur                 gebaseerd                   13
#
#        Topic # 08 Topic # 09   Topic # 10
# 0        voorzien     ruimte       garage
# 1          woning     woning           m2
# 2      verdieping       huis          v.v
# 3      achtertuin               bijkeuken
# 4                      grote       woning
# 5         gelegen       tuin         tuin
# 6     achterzijde                   ruime
# 7       voorzijde       ligt       toilet
# 8          keuken   heerlijk  vrijstaande
# 9         toegang   genieten        grond
# 10    slaapkamers       plek      perceel
# 11      woonkamer  woonkamer       royale
# 12          ruime   waardoor        oprit
# 13     slaapkamer      kamer  slaapkamers
# 14  laminaatvloer      biedt     overloop
# 15        berging     keuken   verdieping
# 16       achterom      licht     badkamer
# 17       badkamer      fijne        vaste
# 18          vaste      mooie     voorzien
# 19       dakkapel       komt     wastafel

# %%
document_topics = model.transform(X=tf_idf_matrix)
document_topics = pd.DataFrame(document_topics)
main_topic = document_topics.idxmax(axis=1)
topics = ["Topic " + str(x) for x in range(1, 11)]
main_topic = main_topic.apply(lambda x: topics[x])

# %%
funda_clean['main_topic'] = main_topic

# %%
funda_clean.loc[lambda x: x.main_topic == "Topic 1"].iloc[:20]
# Out:
#      selling_days  oppervlakte  aantalKamers  aantalBadkamers  koopPrijs  \
# 5             243           68             4              1.0   162500.0
# 17             11          148             4              1.0   300000.0
# 31             20          108             5              1.0   194000.0
# 33             28           80             4              1.0   329000.0
# 43             84          124             4              1.0   270000.0
# 51             19          140             5              1.0   470000.0
# 63              6          118             5              1.0   239000.0
# 67             26          130             6              1.0   300000.0
# 68            180          100             5              1.0   205000.0
# 103           203          126             5              1.0   337000.0
# 117            41          137             5              1.0   375000.0
# 118            28          124             6              1.0   219000.0
# 138            18           86             5              1.0   119000.0
# 142            90          150             5              1.0   310000.0
# 161            77           90             6              1.0   199000.0
# 163            26          147             6              1.0   360000.0
# 169            75          300             7              2.0   775000.0
# 170           141           91             5              1.0   339000.0
# 172             9           79             3              1.0   117500.0
# 176            35          126             5              2.0   369000.0
#
#                                  volledigeOmschrijving  energielabelKlasse_A  \
# 5    In een rustige wijk, op korte afstand van het ...                     0
# 17   VERKOCHT ONDER VOORBEHOUD  Wat maakt u ervan? ...                     0
# 31   In een rustige , kindvriendelijke woonomgeving...                     0
# 33   Opvallende fraaie woonark aan de rand van Utre...                     0
# 43   Deze tussenwoning ligt in de wijk “Buytenwegh”...                     0
# 51   Ruime moderne en luxe afgewerkte hoekwoning me...                     0
# 63   Wilt u rustig wonen met alle noodzakelijke fac...                     0
# 67   Instapklare 2/1 kapwoning met hobby/praktijkru...                     0
# 68   Als je houdt van anders dan anders, dan is dit...                     0
# 172                     0                     0                            0
# 176                     0                     0                            0
#
#      categorieObject_Woonhuis  main_topic
# 5                           1     Topic 1
# 17                          1     Topic 1
# 31                          1     Topic 1
# 33                          1     Topic 1
# 43                          1     Topic 1
# 51                          1     Topic 1
# 63                          1     Topic 1
# 67                          1     Topic 1
# 68                          1     Topic 1
# 103                         1     Topic 1
# 117                         1     Topic 1
# 118                         1     Topic 1
# 138                         1     Topic 1
# 142                         1     Topic 1
# 161                         1     Topic 1
# 163                         1     Topic 1
# 169                         1     Topic 1
# 170                         1     Topic 1
# 172                         1     Topic 1
# 176                         1     Topic 1
#
# [20 rows x 21 columns]

# %% [markdown]
# Now that we have used topic modelling for the description, we can convert them to dummy variables

# %%
#Drop 'volledigeOmschrijving'
del funda_clean['volledigeOmschrijving']

#Convert 'main_topic' to values
funda_clean = pd.get_dummies(funda_clean, prefix = ['main_topic'], columns=['main_topic'])
funda_clean.head()
# Out:
#    selling_days  oppervlakte  aantalKamers  aantalBadkamers  koopPrijs  \
# 0           104           62             3              1.0   139000.0
# 1             0          136             5              1.0   209000.0
# 2           113           70             3              1.0   267500.0
# 3           132          144             5              1.0   349000.0
# 4           123          323             8              1.0   495000.0
#
#    energielabelKlasse_A  energielabelKlasse_A+  energielabelKlasse_A++  \
# 0                     0                      0                       0
# 1                     0                      0                       0
# 2                     0                      0                       0
# 3                     0                      0                       0
# 4                     0                      0                       0
#
#    energielabelKlasse_A+++  energielabelKlasse_A++++  ...  main_topic_Topic 1  \
# 0                        0                         0  ...                   0
# 1                        0                         0  ...                   0
# 2                        0                         0  ...                   0
# 3                        0                         0  ...                   0
# 4                        0                         0  ...                   0
#
#    main_topic_Topic 10  main_topic_Topic 2  main_topic_Topic 3  \
# 0                    0                   0                   0
# 1                    0                   0                   0
# 2                    0                   1                   0
# 3                    0                   0                   1
# 4                    1                   0                   0
#
#    main_topic_Topic 4  main_topic_Topic 5  main_topic_Topic 6  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    main_topic_Topic 7  main_topic_Topic 8  main_topic_Topic 9
# 0                   0                   0                   1
# 1                   0                   0                   1
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Random Forest

# %%
# Libraries and options
# If error [No module named 'sklearn'], in terminal: conda install -c conda-forge scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
# %matplotlib notebook
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %% [markdown]
# Train with the training set, use the validation set for tuning, then generate an accuracy estimate with the testing set.

# %% [markdown]
# The overall steps are:
#
# 1) Divide the available data into training, validation and test set
# 2) Select an algorithm and training parameters
# 3) Train the model using the training set
# 4) Evaluate the model using the validation set
# 5) Repeat steps 2 through 4 using different algorithms and training parameters
# 6) Select the best model and train it using data from the training and validation set
# 7) Assess this final model using the test set.

# %%
y = funda_clean[['selling_days']]
x = funda_clean.drop(['selling_days'],axis = 1)


#set aside 20% of train and test data for evaluation
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=9)

#use the same function above for the validation set
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train,test_size=0.2, random_state=9)

print("X_train shape: {}".format(x_train.shape))
print("X_test shape: {}".format(x_test.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("x_val shape: {}".format(x_val.shape))
print("y_val shape: {}".format(y_val.shape))
# Out:
# X_train shape: (134960, 28)
# X_test shape: (42176, 28)
# y_train shape: (134960, 1)
# y_test shape: (42176, 1)
# x_val shape: (33740, 28)
# y_val shape: (33740, 1)

# %%
#Train the model
from sklearn.metrics import r2_score
Rf = RandomForestRegressor(n_estimators = 5,
                              random_state = 10,
                              n_jobs = -1)
Rf.fit(x_train,y_train)

#Predict the model
Rf_train_pred = Rf.predict(x_train)
Rf_val_pred = Rf.predict(x_val)


#r2 of training set
print('R Squared on training set:', r2_score(y_train,Rf_train_pred))

#r2 of validation set
print('R Squared on validation set:', r2_score(y_val,Rf_val_pred))
# Out:
# RandomForestRegressor(n_estimators=5, n_jobs=-1, random_state=10)
# R Squared on training set: 0.7141882774938996
# R Squared on validation set: -0.13819433861747954

# %%
# %matplotlib inline
plt.figure()
plt.scatter(Rf_val_pred, y_val, alpha=0.2)
plt.xlabel('Random Forest Predictions')
plt.ylabel('True Values')
lims = [0, 200]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
plt.show()
# Out:
# Text(0.5, 0, 'Random Forest Predictions')
# Text(0, 0.5, 'True Values')
# (0.0, 200.0)
# (0.0, 200.0)

# %% [markdown]
# Let's improve this percentage using hyperparameter tuning
#
# There are various hyperparameters that can be controlled in a random forest:
# - N_estimators: The number of decision trees being built in the forest.
# - Criterion: The function that is used to measure the quality of splits in a decision tree (Classification Problem).
# - Max_depth: The maximum levels allowed in a decision tree.
# - Max_features: Maximum number of features used for a node split process.
# - Bootstrap: Bootstrap samples are used when building decision trees if True is selected in bootstrap, else whole data is used for every decision tree.
# - Min_samples_split: This parameter decides the minimum number of samples required to split an internal node.
# - Min_sample_leaf: This parameter sets the minimum number of data point requirements in a node of the decision tree.

# %% [markdown]
# Now we perform model selection, choosing the model that has the best performance on the validation set;

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 3)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2,4]
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
# Use the random grid to search for best hyperparameters in test set
from sklearn.model_selection import GridSearchCV
rf_Model = RandomForestRegressor()
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
# Fit the random search model, this might take a while :)
rf_Grid.fit(x_test, y_test)

# %%
#Pick best parameters
rf_Grid.best_params_

# %%
#Train the model on the validation set, using the best parameters obtained from rf_Grid.best_params_
from sklearn.metrics import r2_score
Rf1 = RandomForestRegressor(n_estimators = 25,
                              random_state = 50,
                              n_jobs = -1)
Rf1.fit(x_val,y_val)


# Make predictions on the test set
Rf_test_pred = Rf1.predict(x_test)



#r2 of test set
print('R Squared on test set:', r2_score(y_test,Rf_test_pred))
# Out:
# RandomForestRegressor(n_estimators=25, n_jobs=-1, random_state=50)
# R Squared on test set: -0.032351657122775546

# %%
#Train the model on the full train set, using the best parameters obtained from rf_Grid.best_params_
from sklearn.metrics import r2_score
Rf2 = RandomForestRegressor(n_estimators = 25,
                              random_state = 50,
                              n_jobs = -1)
Rf2.fit(x_train,y_train)


# Make predictions on the test set
Rf_test_pred = Rf2.predict(x_test)


#r2 of test set
print('R Squared on test set:', r2_score(y_test,Rf_test_pred))
# Out:
# RandomForestRegressor(n_estimators=25, n_jobs=-1, random_state=50)
# R Squared on test set: -0.029948768378068813

# %% [markdown]
# # Neural Networking

# %%
# We are going to import the following libraries
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import warnings
from plotnine import *
warnings.filterwarnings('ignore')

# %%
# Checking the versions of tensorflow and keras
print('tensorflow: %s' % tensorflow.__version__)
print('keras: %s' % keras.__version__)
# Out:
# tensorflow: 2.7.0
# keras: 2.7.0

# %%
# We are going to test the dataset into train, test and validation set
test = funda_final_sellingtime['selling_days']
x = funda_final_sellingtime.drop(['selling_days'],axis = 1)

# We are going to set aside 20% of test data for evaluation
x_train, x_test, y_train, y_test = train_test_split(x,test,test_size=0.2, random_state=8)

# We are going to set aside 80% out of the remaining data for the train set
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train,train_size=0.8, random_state=8)

print("x_train shape: {}".format(x_train.shape))
print("x_test shape: {}".format(x_test.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("x_val shape: {}".format(x_val.shape))
print("y_val shape: {}".format(y_val.shape))
# Out:
# x_train shape: (135433, 6)
# x_test shape: (42324, 6)
# y_train shape: (135433,)
# y_test shape: (42324,)
# x_val shape: (33859, 6)
# y_val shape: (33859,)

# %%
# time to find out how many neurons we need in the input layer
print(f"The number of neurons for the input layer must be: {x_train.shape[1]}")
# Out:
# The number of neurons for the input layer must be: 6

# %%
# The neural network model class instance will be defined
simple_nn = Sequential()
# note that the first command does two things: create a first input layer with 7 nodes, and then a hidden layer with relu activation function
simple_nn.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
# add the output layer with sigmoid function (the sigmoid function is exactly the same as that used in the formulation of logisitc regression
simple_nn.add(Dense(1, activation='relu'))

# %%
# Print the summary of our neural network model class instance
print(simple_nn.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 20)                140
#
#  dense_19 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# We are going to use cross entropy to optimize classification in the backpropagation algorithm.
# For the algorithm for the backpropagation we are going to use adam
simple_nn.compile(loss='mse', optimizer='adam')

# %%
print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))
print("x_val shape: {}".format(x_val.shape))
print("y_val shape: {}".format(y_val.shape))
# Out:
# x_train shape: (135433, 6)
# y_train shape: (135433,)
# x_val shape: (33859, 6)
# y_val shape: (33859,)

# %%
# Making sure all the features/variables are compatible
x_train = np.asarray(x_train).astype('float32')
y_train = np.asarray(y_train).astype('float32')

# %%
# epoch: one forward-and-backprop pass through every row in the training set
# batch: the number of samples that are considered for each backpropagation update of the weights of the network
# Put the neural network on our training set
simple_nn.fit(x_train, y_train, epochs=150, batch_size = 20)
# Out:
# Epoch 1/150
# 6772/6772 [==============================] - 22s 3ms/step - loss: 355288480.0000
# Epoch 2/150
# 6772/6772 [==============================] - 1887s 279ms/step - loss: 8833.2920
# Epoch 3/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: 8833.3594
# Epoch 4/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 16126.4609
# Epoch 5/150
# 6772/6772 [==============================] - 7s 988us/step - loss: 8833.4863
# Epoch 6/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.5371
# Epoch 7/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.4033: 0s - loss: 8838. - ETA: 0s - loss: 8834.95
# Epoch 8/150
# 6772/6772 [==============================] - 6s 877us/step - loss: 8833.6504
# Epoch 9/150
# 6772/6772 [==============================] - 6s 854us/step - loss: 8833.50390s - loss: - ETA:
# Epoch 10/150
# 6772/6772 [==============================] - 6s 834us/step - loss: 8833.2744
# Epoch 11/150
# 6772/6772 [==============================] - 6s 853us/step - loss: 8833.29690s - l
150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8832.9727
# Epoch 138/150
# 6772/6772 [==============================] - 7s 970us/step - loss: 8833.4082
# Epoch 139/150
# 6772/6772 [==============================] - 7s 974us/step - loss: 8833.2510
# Epoch 140/150
# 6772/6772 [==============================] - 7s 987us/step - loss: 8833.5771
# Epoch 141/150
# 6772/6772 [==============================] - 7s 981us/step - loss: 8833.46000s - loss: 8802.
# Epoch 142/150
# 6772/6772 [==============================] - 7s 998us/step - loss: 8833.35840s - - ETA: 0s - los
# Epoch 143/150
# 6772/6772 [==============================] - 7s 976us/step - loss: 8833.35160s - ETA: 0s - loss: 8837. - ETA: 0s - loss: 8838.80 - ETA: 0s - loss: 8843.09
# Epoch 144/150
# 6772/6772 [==============================] - 7s 968us/step - loss: 8833.3535
# Epoch 145/150
# 6772/6772 [==============================] - 7s 998us/step - loss: 8833.5059
# Epoch 146/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3359
# Epoch 147/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3428
# Epoch 148/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 11946.0127
# Epoch 149/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3359
# Epoch 150/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2080

# %% [markdown]
# We can see that the loss function is decreasing

# %%
# see what information has been logged during the training process
simple_nn.history.history.keys()

# plot the training loss over epochs
loss_df = pd.DataFrame(simple_nn.history.history['loss'])
loss_df.columns = ['loss']
loss_df = loss_df.assign(epoch = np.arange(1, 151))

(
    ggplot(loss_df, aes(x='epoch', y='loss')) + geom_point()
)
# Out:
# <ggplot: (151136588930)>

# %%
# We provide our validation dataset to keras to evaluate the loss on the validation dataset per epoch. This way we might detect if the model starts to overfit, for expample.
simple_nn.fit(x_train, y_train, epochs=150, batch_size = 20, validation_data=(x_val, y_val))
# Out:
# Epoch 1/150
# 6772/6772 [==============================] - 6s 953us/step - loss: 8833.1504 - val_loss: 9139.1680
# Epoch 2/150
# 6772/6772 [==============================] - 6s 916us/step - loss: 8833.3018 - val_loss: 9139.0205
# Epoch 3/150
# 6772/6772 [==============================] - 6s 893us/step - loss: 8833.3994 - val_loss: 9139.0557
# Epoch 4/150
# 6772/6772 [==============================] - 6s 872us/step - loss: 8833.3623 - val_loss: 9139.2529
# Epoch 5/150
# 6772/6772 [==============================] - 6s 879us/step - loss: 8833.4551 - val_loss: 9139.0957
# Epoch 6/150
# 6772/6772 [==============================] - 6s 874us/step - loss: 8833.3799 - val_loss: 9139.1582
# Epoch 7/150
# 6772/6772 [==============================] - 6s 893us/step - loss: 8833.2686 - val_loss: 9139.3867
# Epoch 8/150
# 6772/6772 [==============================] - 6s 868us/step - loss: 8833.2119 - val_loss: 9138.9922
# Epoch 9/150
# 6772/6772 [==============================] - 6s 880us/step - loss: 8833.2979 - val_loss: 9139.0029
# Epoch 10/150
# 6772/6772 [==============================] - 6s 877us/step - loss: 8833.3496 - val_loss: 9139.1357
# Epoch 11/150
# 6772/6772 [==============================] - 6s 874us/step - loss: 8833.2744 - val_loss: 9139.1162
# Epoch 12/150
# 6772/6772 [==============================] - 6s 941us/step - loss: 8833.1885 - val_loss: 9139.2529
# Epoch 13/150
150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1670 - val_loss: 9138.8877
# Epoch 121/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.2031 - val_loss: 9138.9619
# Epoch 122/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3760 - val_loss: 9138.9121
# Epoch 123/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.2686 - val_loss: 9139.0693
# Epoch 124/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2236 - val_loss: 9138.9219
# Epoch 125/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3115 - val_loss: 9139.0488
# Epoch 126/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 9708.3496 - val_loss: 9138.9180
# Epoch 127/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1357 - val_loss: 9138.8799
# Epoch 128/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.1670 - val_loss: 9138.8838
# Epoch 129/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2324 - val_loss: 9138.8818
# Epoch 130/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2314 - val_loss: 9139.0469
# Epoch 131/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2373 - val_loss: 9138.8799
# Epoch 132/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 9805.9697 - val_loss: 9138.9443
# Epoch 133/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.1592 - val_loss: 9138.9521
# Epoch 134/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.2148 - val_loss: 9139.1465
# Epoch 135/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1836 - val_loss: 9138.8730
# Epoch 136/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.3115 - val_loss: 9138.9902
# Epoch 137/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8859.1006 - val_loss: 9138.9033
# Epoch 138/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1191 - val_loss: 9139.0859
# Epoch 139/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.1631 - val_loss: 9138.9727
# Epoch 140/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.0762 - val_loss: 9139.0840
# Epoch 141/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1943 - val_loss: 9138.8975
# Epoch 142/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2900 - val_loss: 9138.9082
# Epoch 143/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.0781 - val_loss: 9139.0107
# Epoch 144/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.1299 - val_loss: 9138.9424
# Epoch 145/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2764 - val_loss: 9138.9160
# Epoch 146/150
# 6772/6772 [==============================] - 7s 1ms/step - loss: 8833.2529 - val_loss: 9139.3037
# Epoch 147/150
# 6772/6772 [==============================] - 8s 1ms/step - loss: 8833.2686 - val_loss: 9138.9424
# Epoch 148/150
# 6772/6772 [==============================] - 6s 865us/step - loss: 8833.4385 - val_loss: 9139.0752
# Epoch 149/150
# 6772/6772 [==============================] - 6s 864us/step - loss: 8833.2246 - val_loss: 9139.0352
# Epoch 150/150
# 6772/6772 [==============================] - 6s 866us/step - loss: 8833.1885 - val_loss: 9138.9521

# %%
# We have to import new libraries
import json
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
# plot the training loss over epochs
def plot_loss(nn_model):
    loss_df = pd.DataFrame({
        'train_loss': nn_model.history.history['loss'],
        'val_loss': nn_model.history.history['val_loss']
    })
    loss_df = loss_df.assign(epoch = np.arange(1, 151))

    p = (
        ggplot(loss_df) +
        geom_point(aes(x='epoch', y='train_loss'), color='green') +
        geom_point(aes(x='epoch', y='val_loss'), color='red') +
        scale_x_continuous(breaks = np.arange(0, 150, 10)) +
        ylab("Loss")
    )
    return p

plot_loss(simple_nn)
# Out:
# <ggplot: (151203880165)>

# %%
# We are going to save all the components of the model
# note: We have to sav the training history separately
simple_nn.save('../dataset/simple_nn_model')

print("Storing the fitting history of simple nn to disk")
with open('../dataset/simple_nn_history.json', 'w') as handle:
    json.dump(simple_nn.history.history, handle)
# Out:
# INFO:tensorflow:Assets written to: ../dataset/simple_nn_model\assets
# Storing the fitting history of simple nn to disk

# %%
# we can load the above save model like this:
simple_nn = keras.models.load_model("../dataset/simple_nn_model")
simple_nn

# reload the fitting history like this
with open("../dataset/simple_nn_history.json", "r") as handle:
    simple_nn_history = json.load(handle)

# %%
x_train_validation = np.concatenate([x_train, x_val])
y_train_validation = np.concatenate([y_train, y_val])

# %%
# Since we have determined at least the number of epochs that gives us the best results on the validation dataset, we can train the model on the full train + validation set, and predict on the test set to get a final value for the model performance.
# For the activation function, we are using ReLu (Rectified Linear Unit)
final_nn = Sequential()
final_nn.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
final_nn.add(Dense(1, activation='relu'))
final_nn.compile(loss='binary_crossentropy', optimizer='adam')
final_nn.fit(x_train_validation, y_train_validation, epochs=50, batch_size = 20, verbose=0)
y_hat_test_nn = final_nn.predict(x_test)
y_hat_test_nn = np.where(y_hat_test_nn >= 0.5, 1, 0)
print("The R2 score of the nn model is {}".format(r2_score(y_test, y_hat_test_nn)))
# Out:
# The R2 score of the nn model is -0.7496502765391868

# %%
# Checken if we are not underfitting or underfitting
oversized_nn = Sequential()
oversized_nn.add(Dense(60, input_dim=x_train.shape[1], activation='relu'))
oversized_nn.add(Dense(40, activation='relu'))
oversized_nn.add(Dense(15, activation='relu'))
oversized_nn.add(Dense(1, activation='sigmoid'))
oversized_nn.compile(loss="binary_crossentropy", optimizer="adam")
oversized_nn.fit(x_train, y_train, epochs=150, batch_size = 20, validation_data=(x_val, y_val))
# Out:
# Epoch 1/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -141448037007360.0000 - val_loss: -609912333795328.0000
# Epoch 2/150
# 6772/6772 [==============================] - 9s 1ms/step - loss: -2517662584274944.0000 - val_loss: -5695103012175872.0000
# Epoch 3/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -12210706912903168.0000 - val_loss: -21573929965453312.0000
# Epoch 4/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -36828807692288000.0000 - val_loss: -56937067183079424.0000
# Epoch 5/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -85754914759770112.0000 - val_loss: -123071600672112640.0000624.
# Epoch 6/150
# 6772/6772 [==============================] - 10s 2ms/step - loss: -170495736201347072.0000 - val_loss: -231531825682448384.0000
# Epoch 7/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -305658253927251968.0000 - val_loss: -399311630724235264.0000 ETA: 5s  -  - ETA:
# Epoch 8/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: -506009063717339136.0000 - val_loss: -641671962313097216.0000
# Epoch 9/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -790710832177610752.0000 - val_loss: -978541846659596288.0000139726963487539 - ETA: 6s - loss: -6664111800964874 - ETA: 6 - ETA: 4s - loss: -7079110095 - ETA: 4s - lo - ETA: 2s  - ETA: 1s - loss
# Epoch 10/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -1178135505255006208.0000 - val_loss: -1431692644785848320.0000
# Epoch 11/150
# 6772/6772 [==============================] - 10s 2ms/step - loss: -1691404163214213120.0000 - val_loss: -2025538462630805504.0000
# Epoch 12/150
# 6772/6772 [==============================] - 10s 2ms/step - loss: -2355728126643798016.0000 - val_loss: -2782347434313908224.0000
# Epoch 13/150
# 6772/6772 [==============================] - 10s 2ms/step - loss: -3193035093375451136.0000 - val_loss: -3730685284241637376.0000
# Epoch 14/150
# 6772/6772 [==============================] - 10s 2ms/step - loss: -4235082395193180160.0000 - val_loss: -4899916394579099648.0000
# Epoch 15/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -5511319626413244416.0000 - val_loss: -6326421680944054272.0000: -548964935174
# Epoch 16/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -7047160898800058368.0000 - val_loss: -8027377713985617920.0000
# Epoch 17/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -8888765359755100160.0000 - val_loss: -10060514901475983360.0000
# Epoch 18/150
# 6772/6772 [==============================] - 11s 2ms/step - loss: -11071585112448565248.0000 - val_loss: -12453838354330419200.00001s - loss: -1089
# Epoch 19/150
# 6772/6772 [==============================] - 11s 2ms/step - loss:
150
# 6772/6772 [==============================] - 10s 1ms/step - loss: nan - val_loss: nan
# Epoch 149/150
# 6772/6772 [==============================] - 10s 1ms/step - loss: nan - val_loss: nan
# Epoch 150/150
# 6772/6772 [==============================] - 9s 1ms/step - loss: nan - val_loss: nan

# %%
# Creating a visual overview
plot_loss(oversized_nn)
# Out:
# <ggplot: (151136662098)>

# %% [markdown]
# # Hypertuning of neural network: batches, epochs, layers

# %%
# We have to import new libraries
from scikeras.wrappers import KerasClassifier
import pickle
from sklearn.model_selection import GridSearchCV, PredefinedSplit
import datetime

# %%
# constants 
USE_STORED_SVC_HYPERTUNED_MODELS = True
USE_STORED_SVC_SKLEARNED_HYPERTUNED_MODELS = True
USE_STORED_NN_HYPERTUNED_MODELS = True

# %%
# Creating the model
# We pass the number of neurons as a parameter to the network
def create_model(neurons=1):
    nn_model = Sequential()
    nn_model.add(Dense(neurons, input_dim=x_train.shape[1], activation="relu"))
    nn_model.add(Dense(1, activation='relu'))
    nn_model.compile(loss='binary_crossentropy', optimizer='adam')
    return nn_model

seed = 1234
np.random.seed(seed)

# We are going to turn the keras model into a sklearn compatible model
# note: the neurons parameter needs to be specified in the interface of KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=0, neurons=1)

# %%
# We are defining the grid search parameters
batch_size = [10, 20]
epochs = [100, 150]
neurons = [10, 20, 30]
params_grid = dict(batch_size=batch_size, epochs=epochs, neurons=neurons)

# %%
params_grid
# Out:
# {'batch_size': [10, 20], 'epochs': [100, 150], 'neurons': [10, 20, 30]}

# %%
fold_index = PredefinedSplit([-1]* x_train.shape[0] + [0] * x_val.shape[0])

# %%
#perform grid search with sklearn if needed, otherwise load the grid search already performed
if os.path.exists("../dataset/nn_grid_search.pickle") and USE_STORED_NN_HYPERTUNED_MODELS is True:
    with open('../dataset/nn_grid_search.pickle', 'rb') as handle:
        grid_search_nn = pickle.load(handle)
else:
    start_time = datetime.datetime.now()
    grid_search_nn = GridSearchCV(estimator=model, param_grid=params_grid, n_jobs=-1, cv=fold_index)
    grid_search_nn = grid_search_nn.fit(x_train_validation, y_train_validation)
    end_time = datetime.datetime.now()
    print(f'hypertuning with sklearn grid search for neural networks complete in {round((end_time - start_time).seconds/60, 2)} minutes')
    # store the results of the grid search to disk
with open('../dataset/nn_grid_search.pickle', 'wb') as handle:
    pickle.dump(grid_search_nn, handle)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\j-phh\AppData\Local\Temp\tmp_e2gz69m\assets

# %%
grid_search_nn
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=KerasClassifier(build_fn=<function create_model at 0x000002330967E160>, neurons=1, verbose=0),
#              n_jobs=-1,
#              param_grid={'batch_size': [10, 20], 'epochs': [100, 150],
#                          'neurons': [10, 20, 30]})

# %%
print("The best parameter combination is: {} with score: {}".format(grid_search_nn.best_params_, grid_search_nn.best_score_))
# Out:
# The best parameter combination is: {'batch_size': 10, 'epochs': 100, 'neurons': 10} with score: 0.003071561475530878

# %%
# We are now going to train a model with the best parameters found on train and validation, together:
best_model = create_model(20)
best_model.fit(x_train_validation, y_train_validation, epochs=100, batch_size=10, verbose=0)

# %%
# We can then evaluate the model so trained on the test set:
y_hat_test = best_model.predict(x_test)
y_hat_test = np.where(y_hat_test >= 0.5, 1, 0)
r2_score(y_test, y_hat_test)
# Out:
# -0.7496502765391868
